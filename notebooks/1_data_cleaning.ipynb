# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import seaborn as sns
import sklearn
import sktime
import orbit

# %%
hdb_resale_df = pd.read_csv(r"/workspaces/probabilistic-property/data/raw/HDB_Resale_From_2000.csv")
hdb_resale_df
# Out:
# /tmp/ipykernel_11552/2342360245.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   hdb_resale_df = pd.read_csv(r"/workspaces/probabilistic-property/data/raw/HDB_Resale_From_2000.csv")
#           month        town         flat_type block        street_name  \
# 0       2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1       2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2       2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3       2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4       2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...         ...         ...               ...   ...                ...
# 949716  2016-12      YISHUN            5 ROOM   297       YISHUN ST 20
# 949717  2016-12      YISHUN            5 ROOM   838       YISHUN ST 81
# 949718  2016-12      YISHUN         EXECUTIVE   664       YISHUN AVE 4
# ...

# %%
hdb_resale_df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# dtype: object

# %% [markdown]
# ## Standardize dtypes

# %%
hdb_resale_df[""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspaces/probabilistic-property/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 hdb_resale_df[""]
#
# ...

# %% [markdown]
# ## Address missing values

# %%
hdb_resale_df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# remaining_lease        709050
# resale_price                0
# dtype: int64

# %%
hdb_resale_df[hdb_resale_df["remaining_lease"].isnull()]
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 203518  2000-01  ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 203519  2000-01  ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 203520  2000-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 203521  2000-01  ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 203522  2000-01  ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...         ...         ...        ...   ...               ...          ...
# 912563  1999-12      YISHUN  EXECUTIVE   611      YISHUN ST 61     10 TO 12
# 912564  1999-12      YISHUN  EXECUTIVE   324       YISHUN CTRL     01 TO 03
# 912565  1999-12      YISHUN  EXECUTIVE   392      YISHUN AVE 6     07 TO 09
# 912566  1999-12      YISHUN  EXECUTIVE   356    YISHUN RING RD     04 TO 06
# 912567  1999-12      YISHUN  EXECUTIVE   358    YISHUN RING RD     01 TO 03
#
# ...

# %%
hdb_resale_df[hdb_resale_df["remaining_lease"].notnull()]
# Out:
#           month        town         flat_type block        street_name  \
# 0       2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1       2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2       2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3       2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4       2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...         ...         ...               ...   ...                ...
# 949716  2016-12      YISHUN            5 ROOM   297       YISHUN ST 20
# 949717  2016-12      YISHUN            5 ROOM   838       YISHUN ST 81
# 949718  2016-12      YISHUN         EXECUTIVE   664       YISHUN AVE 4
# 949719  2016-12      YISHUN         EXECUTIVE   325        YISHUN CTRL
# 949720  2016-12      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
2017-1979
# Out:
# 38

# %%
37+61
# Out:
# 98

# %% [markdown]
# # Generate Plots

# %%
import os
os.getcwd()
# Out:
# '/workspaces/probabilistic-property/notebooks'
